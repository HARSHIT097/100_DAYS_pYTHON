# %% [markdown]
# <a href="https://colab.research.google.com/github/HARSHIT097/100_DAYS_pYTHON/blob/main/Drproject_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #pre requisite
#
#
# *   linux commands
# *   python

# %%
# !ls
# Out:
# sample_data

# %%
# !cat /proc/meminfo

# %% [markdown]
# #Moving to Python
# hello python

# %% [markdown]
# # Some more to logic

# %% [markdown]
# # Tricks to python

# %% [markdown]
# ## R and Python Together

# %%
##using R in python notebook

# !pip3 install rpy2

# %%
# %load_ext rpy2.ipython
# %R require(ggplot2)
# Out:
# R[write to console]: Loading required package: ggplot2
# <rpy2.robjects.vectors.BoolVector object at 0x7f32104e9e60> [RTYPES.LGLSXP]
# R classes: ('logical',)
# [       1]

# %%
import pandas as pd
df = pd.DataFrame({
        'Class': ['A', 'A', 'A', 'V', 'V', 'A', 'A', 'A'],
        'X': [4, 3, 5, 2, 1, 7, 7, 5],
        'Y': [0, 4, 3, 6, 7, 10, 11, 9],
        'Z': [1, 2, 3, 1, 2, 3, 1, 2]
    })

# %%
# %%R -i df
# ggplot(data = df) + geom_point(aes(x = X, y= Y, color = Class, size = Z))

# %% [markdown]
# ## zip function:
# The purpose of this zip function is to “make an iterator that aggregates elements from each of the iterables”.

# %%
# Combining multiple lists using zip function

list1 = ['Analytics', 'Data', 'Data', 'Statistics']
list2 = ['Vidhya', 'Science', 'Hack', 'and']
list3 = ['Community', 'Trend', 'Summit 2019', 'Probability']

for w1, w2, w3 in zip(list1,list2,list3) :
    print(w1,w2,w3)
# Out:
# Analytics Vidhya Community
# Data Science Trend
# Data Hack Summit 2019
# Statistics and Probability

# %% [markdown]
# ## gmplots: Google Maps
#
# gmplot: Plot the GPS Coordinates in your Dataset on Google Maps
#
# gmplot provides an amazing interface to generate HTML and JavaScript to render all the data we’d like on top of Google Maps.

# %%
# !pip3 install gmplot

# %%
import pandas as pd
import gmplot
data = pd.read_csv('3D_spatial_network.csv')
data.head()
# Out:
#       OSM_ID  LONGITUDE   LATITUDE   ALTITUDE
# 0  144552912   9.349849  56.740876  17.052772
# 1  144552912   9.350188  56.740679  17.614840
# 2  144552912   9.350549  56.740544  18.083536
# 3  144552912   9.350806  56.740484  18.279465
# 4  144552912   9.351053  56.740486  18.422974

# %%
# latitude and longitude list 
latitude_list = data['LATITUDE'] 
longitude_list = data['LONGITUDE'] 

# center co-ordinates of the map 
gmap = gmplot.GoogleMapPlotter( 56.730876,9.349849,9)

# plot the co-ordinates on the google map 
gmap.scatter( latitude_list, longitude_list, '# FF0000', size = 40, marker = True) 

# the following code will create the html file view that in your web browser 
gmap.heatmap(latitude_list, longitude_list) 

gmap.draw( "mymap.html" )
# Out:
# /usr/local/lib/python3.7/dist-packages/gmplot/color.py:194: UserWarning: Color '# FF0000' isn't supported.
#   warnings.warn("Color '%s' isn't supported." % color)

# %%
from IPython.display import HTML
from IPython.display import display
display(filename='mymap.html')

# %%
# %%html
# <a href="mymap.html">link</a>
# Out:
# <a href="mymap.html">link</a>

# %% [markdown]
# ## category_encoders:
#  Encode your Categorical Variables using 15 Different Encoding Schemes
#
# category_encoders supports around 15 different encoding methods, such as:
#
# Hashing Encoding
#
# LeaveOneOut Encoding
#
# Ordinal Encoding
#
# Binary Encoding
#
# Target Encoding
# All the encoders are fully compatible with sklearn-transformers so they can easily be used in your existing scripts. Also, category_encoders supports NumPy arrays and Pandas dataframes. You can read more about category_encoders here.

# %%
# !pip3 install category-encoders

# %%
import pandas as pd 
import category_encoders as ce 

# create a Dataframe 
data = pd.DataFrame({ 'gender' : ['Male', 'Female', 'Male', 'Female', 'Female'],
                      'class' : ['A','B','C','D','A'],
                      'city' : ['Delhi','Gurugram','Delhi','Delhi','Gurugram'] }) 
                                                                                      
data.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
#    gender class      city
# 0    Male     A     Delhi
# 1  Female     B  Gurugram
# 2    Male     C     Delhi
# 3  Female     D     Delhi
# 4  Female     A  Gurugram

# %%
# One Hot Encoding 
# create an object of the One Hot Encoder 

ce_OHE = ce.OneHotEncoder(cols=['gender','city']) 

# transform the data 
data = ce_OHE.fit_transform(data) 
data.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/category_encoders/utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):
#    gender_1  gender_2 class  city_1  city_2
# 0         1         0     A       1       0
# 1         0         1     B       0       1
# 2         1         0     C       1       0
# 3         0         1     D       1       0
# 4         0         1     A       0       1

# %% [markdown]
# ##progress_apply:
#  Monitor the Time you Spend on Data Science Tasks

# %%
# !pip install tqdm
# Out:
# ERROR: Could not find a version that satisfies the requirement pysal.lib.cg (from versions: none)
# ERROR: No matching distribution found for pysal.lib.cg

# %%
# importing modules
from tqdm import trange
from time import sleep
   
# creating loop
for i in trange(10, desc ="loop "):
           
        # slowing the for loop
        sleep(0.1)
# Out:
# loop : 100%|██████████| 10/10 [00:01<00:00,  9.85it/s]

# %%
# importing modules
from tqdm import tnrange
from time import sleep
  
# creating loop
for i in tnrange(2, desc ="loop 1"):
      
    # creating nested loop
    for j in tnrange(5, desc ="loop 2"):
          
        # slowing the for loop
        sleep(0.2)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: TqdmDeprecationWarning: Please use `tqdm.notebook.trange` instead of `tqdm.tnrange`
# ...
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: TqdmDeprecationWarning: Please use `tqdm.notebook.trange` instead of `tqdm.tnrange`
#   if __name__ == '__main__':
# ...

# %%
# importing modules
import time
import sys
from tqdm import trange
  
# random function
def random_task():
    time.sleep(0.5)    
  
# another random function
def another_random_task():
    time.sleep(0.2)
  
# Outer loop
for i in trange(3, file=sys.stdout, desc='Outer loop'):
    random_task()
      
    # inner loop
    for j in trange(5,file=sys.stdout, desc='Inner loop'):
        another_random_task()
# Out:
# ...
# Outer loop: 100%|██████████| 3/3 [00:04<00:00,  1.54s/it]

# %%
# !pip install pysal

# %%
import pandas as pd
from tqdm._tqdm_notebook import tqdm_notebook
#from pysal.lib.cg import harcdist
import pysal as pl
tqdm_notebook.pandas()
data = pd.read_csv('3D_spatial_network.csv')
data.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/tqdm/std.py:658: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
#       OSM_ID  LONGITUDE   LATITUDE   ALTITUDE
# 0  144552912   9.349849  56.740876  17.052772
# 1  144552912   9.350188  56.740679  17.614840
# 2  144552912   9.350549  56.740544  18.083536
# 3  144552912   9.350806  56.740484  18.279465
# 4  144552912   9.351053  56.740486  18.422974

# %%
# calculate the distance of each data point from # (Latitude, Longitude) = (58.4442, 9.3722) 

def calculate_distance(x): 
   return pl.lib.cg.harcdist((x['LATITUDE'],x['LONGITUDE']),(58.4442, 9.3722)) 
   
data['DISTANCE'] = data.progress_apply(calculate_distance,axis=1)

# %%
# !pip install keras-tqdm

# %%
from keras_tqdm import TQDMNotebookCallback
# keras, model definition...
model.fit(X_train, Y_train, verbose=0, callbacks=[TQDMNotebookCallback()])

# %%
from keras_tqdm import TQDMCallback
# keras, model definition...
model.fit(X_train, Y_train, verbose=0, callbacks=[TQDMCallback()])

# %% [markdown]
# ##  grouper: Grouping Time Series Data

# %%
import pandas as pd 

data = pd.read_excel('/content/sales-data_.xlsx') 
data.head()
# Out:
#                           name  ext price                 date
# 0                   Barton LLC    3380.91  2014-01-01 07:21:51
# 1              Trantow-Barrows     -63.16  2014-01-01 10:00:47
# 2                    Kulas Inc    2086.10  2014-01-01 13:24:58
# 3  Kassulke, Ondricka and Metz     863.05  2014-01-01 15:05:22
# 4                Jerde-Hilpert     499.26  2014-01-01 23:26:55

# %%
#convert the date column into a DateTime format
data['date'] = pd.to_datetime(data['date'])


data.set_index('date').groupby('name')["ext price"].resample("M").sum()
# Out:
# name        date
# Barton LLC  2014-01-31     6177.57
#             2014-02-28    12218.03
#             2014-03-31     3513.53
#             2014-04-30    11474.20
#             2014-05-31    10220.17
#                             ...
# Will LLC    2014-08-31     1439.82
#             2014-09-30     4345.99
#             2014-10-31     7085.33
#             2014-11-30     3210.44
#             2014-12-31    12561.21
# Name: ext price, Length: 240, dtype: float64

# %%
data.groupby(['name', pd.Grouper(key='date', freq='M')])['ext price'].sum()
# Out:
# name        date
# Barton LLC  2014-01-31     6177.57
#             2014-02-28    12218.03
#             2014-03-31     3513.53
#             2014-04-30    11474.20
#             2014-05-31    10220.17
#                             ...
# Will LLC    2014-08-31     1439.82
#             2014-09-30     4345.99
#             2014-10-31     7085.33
#             2014-11-30     3210.44
#             2014-12-31    12561.21
# Name: ext price, Length: 240, dtype: float64

# %%
#unstack: Transform the Index into Columns of your Dataframe
data.groupby(['name', pd.Grouper(key='date', freq='M')])['ext price'].sum().unstack()
# Out:
# date                             2014-01-31  2014-02-28  ...  2014-11-30  2014-12-31
# name                                                     ...
# Barton LLC                          6177.57    12218.03  ...     4901.14     2772.90
# Cronin, Oberbrunner and Spencer     1141.75    13976.26  ...     6021.11     7640.60
# Frami, Hills and Schmidt            5112.34     4124.53  ...     7221.02    16249.81
# Fritsch, Russel and Anderson       15130.77     9595.35  ...     6233.08    12345.64
# Halvorson, Crona and Champlin       9997.17     7082.15  ...     4017.19     2900.51
# Herman LLC                         10749.84     5831.40  ...     5049.15     4664.54
# Jerde-Hilpert                      11274.33     4088.40  ...     7128.39     6941.99
# Kassulke, Ondricka and Metz         7322.83     3061.12  ...     8836.82     4425.22
# Keeling LLC                         6847.86     3383.45  ...    10310.96    13247.88
# ...

# %% [markdown]
# ## %%time: Check the Running Time of a Particular Block of Python Code

# %%
# %%time 
def myfunction(x) : 
    for i in range(1,100000,1) : 
        i=i+1
# Out:
# CPU times: user 4 µs, sys: 1 µs, total: 5 µs
# Wall time: 9.3 µs

# %%
data.head()
# Out:
#                           name  ext price                date
# 0                   Barton LLC    3380.91 2014-01-01 07:21:51
# 1              Trantow-Barrows     -63.16 2014-01-01 10:00:47
# 2                    Kulas Inc    2086.10 2014-01-01 13:24:58
# 3  Kassulke, Ondricka and Metz     863.05 2014-01-01 15:05:22
# 4                Jerde-Hilpert     499.26 2014-01-01 23:26:55

# %% [markdown]
# %matplotlib notebook will lead to interactive plots embedded within the notebook
# %matplotlib inline will lead to static images of your plot embedded in the notebook

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
#get resizable and zoomable plots within your notebook!
# scatter plot of some data # try this on your dataset
plt.scatter(data['name'],data['ext price'])
plt.show()
# Out:
# <div id='08d0f989-de3e-4ed5-b10f-aff0dda1d138'></div>
# <div id='8fbfa8e2-51dc-44cd-bcc8-201fee103671'></div>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# scatter plot of some data # try this on your dataset
plt.scatter(data['quantity'],data['unit price'])

# %% [markdown]
# ## generating report : pandas profiling
#
# Warnings like: Item_Identifier has a high cardinality: 1559 distinct values Warning
# Frequency Count of all categorical variables
# Quantile and Descriptive statistics of numerical variables
# Correlation Plot

# %%
#generates a detailed report of our data in just one line of code!
import pandas as pd 
import pandas_profiling 

# read the dataset 
data = pd.read_csv('/content/sample_data/california_housing_test.csv') 
pandas_profiling.ProfileReport(data)
